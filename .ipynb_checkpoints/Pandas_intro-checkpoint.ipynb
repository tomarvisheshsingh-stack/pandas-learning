# %%
import pandas as pd

# %%
data = {
    "Name": ["Vishesh", "Rahul", "Ankit"],
    "Age": [21, 22, 20],
    "Marks": [85, 90, 78]
}

df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age  Marks
# 0  Vishesh   21     85
# 1    Rahul   22     90
# 2    Ankit   20     78
